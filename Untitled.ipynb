# %% [markdown]
# # Build feature matrices
# > 1. Load raw_partD.csv

# %%
import pandas as pd
import src.scripts as src

# %%
partD_df = src.read_from_efs('raw_PartD.csv')
id_df = src.read_from_efs('id_df.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-b1ba894f4f63> in <module>()
# ----> 1 partD_df = src.read_from_efs('raw_PartD.csv')
#       2 id_df = src.read_from_efs('id_df.csv')
#
# ~/SageMaker/healthcare-fraud/src/scripts.py in read_from_efs(f_name, **kwargs)
#      14     '''
#      15     f_path = '~/SageMaker/efs/DrFraud/data/{}'.format(f_name)
# ---> 16     df = pd.read_csv(f_path, index_col=0, low_memory=False, **kwargs)
#      17     return df
#      18
#
# ...

# %%
id_df.head()
